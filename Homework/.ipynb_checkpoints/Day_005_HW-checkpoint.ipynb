# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = 'D:/ML_100marathon/Home_Credit_Default_Risk'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
app_train['AMT_INCOME_TOTAL'].mean()
# Out:
# 168797.9192969845

# %%
app_train['AMT_ANNUITY'].sum()
# Out:
# 8335859368.5

# %% [markdown]
# ##### Cumulative sum

# %%
app_train["AMT_ANNUITY"].cumsum()
# Out:
# 0         2.470050e+04
# 1         6.039900e+04
# 2         6.714900e+04
# 3         9.683550e+04
# 4         1.187010e+05
# 5         1.462185e+05
# 6         1.875195e+05
# 7         2.295945e+05
# 8         2.634210e+05
# 9         2.836710e+05
# 10        3.048480e+05
# 11        3.155265e+05
# 12        3.214080e+05
# 13        3.503745e+05
# 14        3.831525e+05
# 15        4.033125e+05
# 16        4.294620e+05
# 17        4.429620e+05
# 18        4.508370e+05
# 19        4.684005e+05
# 20        4.897755e+05
# 21        5.273370e+05
# 22        5.598585e+05
# 23        5.837085e+05
# 24        5.964120e+05
# 25        6.074865e+05
# 26        6.345630e+05
# 27        6.583905e+05
# 28        7.160670e+05
# 29        7.250670e+05
#               ...
# 307481    8.335138e+09
# 307482    8.335173e+09
# 307483    8.335189e+09
# 307484    8.335225e+09
# 307485    8.335234e+09
# 307486    8.335252e+09
# 307487    8.335283e+09
# 307488    8.335297e+09
# 307489    8.335320e+09
# ...

# %%
app_train['AMT_CREDIT'].describe()
# Out:
# count    3.075110e+05
# mean     5.990260e+05
# std      4.024908e+05
# min      4.500000e+04
# 25%      2.700000e+05
# 50%      5.135310e+05
# 75%      8.086500e+05
# max      4.050000e+06
# Name: AMT_CREDIT, dtype: float64

# %% [markdown]
# ##### Count the number of non-NA values

# %%
app_train['CNT_CHILDREN'].count()
# Out:
# 307511

# %%
app_train['AMT_CREDIT'].max()
# Out:
# 4050000.0

# %%
app_train['AMT_CREDIT'].min()
# Out:
# 45000.0

# %%
app_train['AMT_CREDIT'].median()
# Out:
# 513531.0

# %%
app_train['AMT_CREDIT'].var()
# Out:
# 161998825566.80032

# %%
app_train['AMT_CREDIT'].std()
# Out:
# 402490.776995946

# %%
app_train['AMT_CREDIT'].skew()
# Out:
# 1.2347784971349398

# %%
app_train['AMT_CREDIT'].kurt()
# Out:
# 1.9340413008324937

# %%
app_train.corr()
# Out:
#                              SK_ID_CURR    TARGET  CNT_CHILDREN  \
# SK_ID_CURR                     1.000000 -0.002108     -0.001129
# TARGET                        -0.002108  1.000000      0.019187
# CNT_CHILDREN                  -0.001129  0.019187      1.000000
# AMT_INCOME_TOTAL              -0.001820 -0.003982      0.012882
# AMT_CREDIT                    -0.000343 -0.030369      0.002145
# AMT_ANNUITY                   -0.000433 -0.012817      0.021374
# AMT_GOODS_PRICE               -0.000232 -0.039645     -0.001827
# REGION_POPULATION_RELATIVE     0.000849 -0.037227     -0.025573
# DAYS_BIRTH                    -0.001500  0.078239      0.330938
# DAYS_EMPLOYED                  0.001366 -0.044932     -0.239818
# DAYS_REGISTRATION             -0.000973  0.041975      0.183395
# DAYS_ID_PUBLISH               -0.000384  0.051457     -0.028019
# OWN_CAR_AGE                    0.001818  0.037612      0.008494
# FLAG_MOBIL                     0.002804  0.000534      0.001041
# ...

# %%
app_train[['AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE']].cov()
# Out:
#                    AMT_CREDIT   AMT_ANNUITY  AMT_GOODS_PRICE
# AMT_CREDIT       1.619988e+11  4.492695e+09     1.467708e+11
# AMT_ANNUITY      4.492695e+09  2.100684e+08     4.150001e+09
# AMT_GOODS_PRICE  1.467708e+11  4.150001e+09     1.364907e+11

# %%
#import matplotlib.pyplot as plt
app_train['AMT_INCOME_TOTAL'].plot()

# %%
app_train['AMT_INCOME_TOTAL'].hist(bins=100)

# %% [markdown]
# ##### 篩選掉過大的值再畫圖

# %%
dat=app_train.loc[app_train['AMT_INCOME_TOTAL'] < 500000]
dat['AMT_INCOME_TOTAL'].hist(bins=50)
